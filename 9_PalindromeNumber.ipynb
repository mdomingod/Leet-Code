# %% [markdown]
# # 9. Palindrome Number
# Given an integer x, return true if x is a palindrome, and false otherwise.
#
# Example 1:
#
# Input: x = 121
# Output: true
# Explanation: 121 reads as 121 from left to right and from right to left.
#
# Example 2:
#
# Input: x = -121
# Output: false
# Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.
#
# Example 3:
#
# Input: x = 10
# Output: false
# Explanation: Reads 01 from right to left. Therefore it is not a palindrome.
#
#
# Constraints:
#
# -231 <= x <= 231 - 1
#
#
# Follow up: Could you solve it without converting the integer to a string?

# %%
class Solution:
    def isPalindrome(self, x: int) -> bool:
        if x

# %% [markdown]
# ### 1. self
#
# `self` refers to the current object (instance) of a class.
#
# On LeetCode, your solution is usually written inside a class:
#
# ```
# class Solution:
#     def isPalindrome(self, x: int) -> bool:
#         ...
# ```
#
# ```
# sol = Solution()
# sol.isPalindrome(121)
# ```

# %% [markdown]
# # Solution

# %%
class Solution:
	def isPalindrome(self, x: int) -> bool:
		rev = 0
		org = x
		while x > 0:
			l = x % 10
			rev = rev * 10 + l  
			x = x // 10

		if org == rev:
			return True
		else:
			return False

sol = Solution()
print(sol.isPalindrome(12321))
print(sol.isPalindrome(121))
print(sol.isPalindrome(-121))
print(sol.isPalindrome(10))
print(sol.isPalindrome(12345654321))
print(sol.isPalindrome(123456654321))
print(sol.isPalindrome(123456543321))
# Out:
# True
# True
# False
# False
# True
# True
# False

# %% [markdown]
# # Development

# %% [markdown]
# ## Built-in Types: int
# Documentation: https://docs.python.org/3/library/stdtypes.html#numeric-types-int-float-complex

# %%
x = 123456
# Modulus operator to get the last digit
m = x % 10
# Integer division to remove the last digit
i = x // 10

print(f"Last digit: {m}, Remaining number: {i}")
# Out:
# Last digit: 6, Remaining number: 12345

# %%
# Building block 1: taking a number apart
##  Write a small loop that prints the digits of 1234 one at a time, from last to first (4, 3, 2, 1). 
## When should the loop stop? Think about what x becomes after you have removed every digit.

x = 1234
while x > 0:
	y = x % 10
	x = x // 10
	print(y)
# Out:
# 4
# 3
# 2
# 1

# %%
# Building block 2: building a number up.
## Now do the reverse. How do you "stick" a new digit onto the end of a number?
## You have 12 and want 123. What math operation turns 12 into 120? Then what do you add?

x = 1234
rev = 0
while x > 0:
	l = x % 10
	rev = rev * 10 + l  
	x = x // 10
	print(rev)
	
print(" ")
print(rev)
# Out:
# 4
# 43
# 432
# 4321
#
# 4321

# %%
x = 12321
rev = 0
org = x
while x > 0:
	l = x % 10
	rev = rev * 10 + l  
	x = x // 10

	#print(rev)

#print(" ")
print(f"Reverse: {rev}")
print(f"x: {x}")
print(f"Orginal x: {org}")
# Out:
# Reverse: 12321
# x: 0
# Orginal x: 12321

# %%
org == rev
# Out:
# True

# %%
class Solution:
	def isPalindrome(self, x: int) -> bool:
		rev = 0
		org = x
		while x > 0:
			l = x % 10
			rev = rev * 10 + l  
			x = x // 10

		if org == rev:
			return True
		else:
			return False

# %%
sol = Solution()
sol.isPalindrome(12321)
# Out:
# True

# %%
sol.isPalindrome(-121)
# Out:
# False

# %%
sol.isPalindrome(1234)
# Out:
# False

# %%
sol.isPalindrome(121)
# Out:
# True

# %% [markdown]
# ## Built-in Types: str
# Documentation: https://docs.python.org/3/library/stdtypes.html#text-sequence-type-str

# %%
# str()
s = str(x)
s[::-1]  # Reverse the string

class Solution:
	def isPalindrome(self, x: int) -> bool:
		s = str(x)
		s[::-1]  # Reverse the string
		if s == s[::-1]:
			return True
		return False

# %%
sol = Solution()
sol.isPalindrome(123)
# Out:
# False

# %%
sol = Solution()
sol.isPalindrome(-121)
# Out:
# False

# %%
sol = Solution()
sol.isPalindrome(121)
# Out:
# True

# %% [markdown]
# ## Python Tutorial: Data Structures / Slicing
# To understand [::-1].
#
# Documentation: https://docs.python.org/3/tutorial/introduction.html#strings
