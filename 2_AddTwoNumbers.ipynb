# %% [markdown]
# # Enunciat
# You are given two **non-empty** linked lists representing two non-negative integers. The digits are stored in **reverse order**, and each of their nodes contains a single digit. Add the two numbers and return the sum as a linked list.
#
# You may assume the two numbers do not contain any leading zero, except the number 0 itself.
#
# Input: l1 = [**2,4,3**], l2 = [**5,6,4**]
# Output: [**7,0,8**]
# Explanation: 342 + 465 = 807.
# Example 2:
#
# Input: l1 = [**0**], l2 = [**0**]
# Output: [**0**]
# Example 3:
#
# Input: l1 = [**9,9,9,9,9,9,9**], l2 = [**9,9,9,9**]
# Output: [**8,9,9,9,0,0,0,1**]
#
#
# Constraints:
#
# The number of nodes in each linked list is in the range [1, 100].
# 0 <= Node.val <= 9
# It is guaranteed that the list represents a number that does not have leading zeros.

# %%
# Definition of variables
l1 = [1, 2, 3]
var = ""

# For loop to join the values of the list in a just one variable string.
for i in range(len(l1)-1, -1, -1):
    var += str(l1[i])

# For checking the last output
print(var)
print(type(var))

# Convert the string into number int()
var = int(var)

# For checking the last output
print(var)
type(var)
# Out:
# 321
# <class 'str'>
# 321
# int

# %%
# Definition of variables
l2 = [2, 3, 4]
var2 = ""

# For loop to join the values of the list in a just one variable string.
for i in range(len(l2)-1, -1, -1):
    var2 += str(l2[i])

# For checking the last output
print(var2)
print(type(var2))

# Convert the string into number int()
var2 = int(var2)

# For checking the last output
print(var2)
type(var2)
# Out:
# 432
# <class 'str'>
# 432
# int

# %%
var_var2 = var + var2
var_var2 == 321+432
var_var2
# Out:
# 753

# %%
str_var_var2 = str(var_var2)
reverse = ""

print(str_var_var2)

for n in range(len(var_var2)-1, -1, -1):
    
    reverse += str(var_var2[n])
    reverse = int(reverse)

reverse
# Out:
# 753
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 6
#       2 reverse = ""
#       4 print(str_var_var2)
# ----> 6 for n in range(len(var_var2)-1, -1, -1):
#       8     reverse += str(var_var2[n])
#       9     reverse = int(reverse)
#
# TypeError: object of type 'int' has no len()

# %%
class Solution:
    def addTwoNumbers(self, l1, l2):


        # Definition of variable l1
        self.l1 = l1
        var = ""

        # For loop to join the values of the list in a just one variable string.
        for i in range(len(l1)):
            var += str(l1[i])

        # Convert the string into number int()
        var = int(var)


        # Definition of variable l2
        self.l2 = l2
        var2 = ""

        # For loop to join the values of the list in a just one variable string.
        for i in range(len(l2)):
            var2 += str(l2[i])

        # Convert the string into number int()
        var2 = int(var2)

        
        # Sum of two int var from l1 and l2:
        var_var2 = var + var2

        reverse = []
        for n in range(len(var_var2)-1, -1, -1):
            reverse.append(n)

        return var_var2

# %% [markdown]
# l1 = [9,9,9,9,9,9,9], l2 = [9,9,9,9]

# %%
l1 = [9,9,9,9,9,9,9]
l2 = [9,9,9,9]

solution = Solution()
solution.addTwoNumbers(l1, l2)
# Out:
# 10009998
